# %%
library(readxl)

# %%
data <- read_excel('projectdata_FW2022.xlsx')
rownames(data) <- data$year
data
# Out:
# Warning message:
# “Setting row names on a tibble is deprecated.”
#     year       CPICANALL CPIGROCANALL CPICANEXC CPICANSER CPICANGDS CPICANENG
# 1   1961-01-01 15.7      1.2903226    17.3      13.2      17.5      11.5
# 2   1961-02-01 15.7      1.2903226    17.3      13.2      17.5      11.5
# 3   1961-03-01 15.7      1.9480519    17.3      13.2      17.5      11.5
# 4   1961-04-01 15.7      1.2903226    17.3      13.2      17.5      11.5
# 5   1961-05-01 15.7      1.2903226    17.4      13.3      17.5      11.4
# 6   1961-06-01 15.7      1.2903226    17.3      13.3      17.5      11.3
# 7   1961-07-01 15.7      1.2903226    17.2      13.3      17.5      11.4
# 8   1961-08-01 15.7      1.2903226    17.2      13.3      17.5      11.5
# 9   1961-09-01 15.7      1.2903226    17.4      13.4      17.5      11.5
# 10  1961-10-01 15.7      0.0000000    17.4      13.4      17.5      11.5
# 11  1961-11-01 15.7      0.0000000    17.4      13.4      17.5      11.5
# ...

# %%
summary(data)
# Out:
#       year                           CPICANALL       CPIGROCANALL
#  Min.   :1961-01-01 00:00:00.000   Min.   : 15.70   Min.   :-0.9499
#  1st Qu.:1976-07-01 00:00:00.000   1st Qu.: 31.30   1st Qu.: 1.6627
#  Median :1992-01-01 00:00:00.000   Median : 83.30   Median : 2.6026
#  Mean   :1991-12-31 16:18:02.416   Mean   : 75.31   Mean   : 3.7844
#  3rd Qu.:2007-07-01 00:00:00.000   3rd Qu.:111.80   3rd Qu.: 4.7619
#  Max.   :2023-01-01 00:00:00.000   Max.   :154.00   Max.   :12.8959
#
#    CPICANEXC        CPICANSER        CPICANGDS       CPICANENG
#  Min.   : 17.20   Min.   : 13.20   Min.   : 17.5   Min.   : 11.00
#  1st Qu.: 32.90   1st Qu.: 29.90   1st Qu.: 32.7   1st Qu.: 22.80
#  Median : 84.40   Median : 80.60   Median : 86.2   Median : 77.30
#  Mean   : 74.52   Mean   : 76.28   Mean   : 74.2   Mean   : 80.28
#  3rd Qu.:109.00   3rd Qu.:115.30   3rd Qu.:107.6   3rd Qu.:132.30
#  Max.   :144.30   Max.   :166.10   Max.   :142.4   Max.   :242.50
#
# ...
