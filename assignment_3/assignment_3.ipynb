# %%
data <- read.csv(file='dataproject_Fall.csv')
data
# Out:
#     DATE    TSX      RETAIL    POP    LFC    PTM   UNEMP EI     CPIT  CPIC  ⋯
# 1   1982-01 1786.91                   NA     NA    NA    NA     49.9  52.2  ⋯
# 2   1982-02 1671.34                   NA     NA    NA    NA     50.6  52.8  ⋯
# 3   1982-03 1587.83                   NA     NA    NA    NA     51.5  53.5  ⋯
# 4   1982-04 1548.17                   NA     NA    NA    NA     51.8  53.8  ⋯
# 5   1982-05 1523.68                   NA     NA    NA    NA     52.6  54.5  ⋯
# 6   1982-06 1366.80                   NA     NA    NA    NA     53.2  55.1  ⋯
# 7   1982-07 1411.90                   NA     NA    NA    NA     53.5  55.4  ⋯
# 8   1982-08 1613.32                   NA     NA    NA    NA     53.7  55.6  ⋯
# 9   1982-09 1602.01                   NA     NA    NA    NA     53.8  55.9  ⋯
# 10  1982-10 1774.04                   NA     NA    NA    NA     54.2  56.3  ⋯
# 11  1982-11 1838.31                   NA     NA    NA    NA     54.7  56.6  ⋯
# ...
